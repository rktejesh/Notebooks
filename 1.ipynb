# %% [markdown]
# <a href="https://colab.research.google.com/github/rktejesh/Notebooks/blob/main/1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %%
url = 'https://github.com/rktejesh/mywebpage/blob/master/Omnify-Analyst-Intership-Task.xlsx?raw=true'
data = pd.read_excel(url, sheet_name="Google Ads Data")

# %%
data['Payment ($)'] = data['Payment ($)'].str.replace('$', '')
data['Payment ($)'] = data['Payment ($)'].str.replace(',', '')
data['Payment ($)'] = data['Payment ($)'].astype(float)
data['Payment ($)'] = data['Payment ($)'].fillna(0)
data.head()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   """Entry point for launching an IPython kernel.
#         Week                  Campaign                            Ad group  \
# 0 2021-01-25       EK_Generic_Swimming       Pool_Reservation_System_Exact
# 1 2021-01-25       EK_Generic_Swimming              Pool_Booking_App_Exact
# 2 2021-01-25  EK_Generic_Quad-Tok_Yoga  Yoga_Studio_Booking_Software_Broad
# 3 2021-01-25       EK_Generic_Swimming     Pool_Scheduling_Software_Phrase
# 4 2021-01-25    EK_Generic_Swimming_UK     Pool_Reservation_Software_Broad
#
#   Keyword type                Search Keyword Currency  Clicks  Impressions  \
# 0        Exact       pool reservation system      USD       2           17
# ...

# %% [markdown]
# # New Section

# %%
"""
Go through the dataset, and deliver the following:

- Create a combined report with all key metrics (esp: Spends and Returns) in a weekly and monthly format. 
Decide the number of data fields you would like to showcase here.

- Which is the most profitable channel

- Which category/keyword is the most profitable

- Look for insights by analysing data points on time series graphs

- Analyse the Impact of geography

Feel free to creatively bring in additional insights from the data set
"""
# Out:
# '\nGo through the dataset, and deliver the following:\n\n- Create a combined report with all key metrics (esp: Spends and Returns) in a weekly and monthly format. \nDecide the number of data fields you would like to showcase here.\n\n- Which is the most profitable channel\n\n- Which category/keyword is the most profitable\n\n- Look for insights by analysing data points on time series graphs\n\n- Analyse the Impact of geography\n\nFeel free to creatively bring in additional insights from the data set\n'

# %%
df1 = data.groupby('Week')['Cost ($)'].sum()
df1
# Out:
# Week
# 2021-01-25    154.79
# 2021-02-01    192.58
# 2021-02-08    216.13
# 2021-02-15    235.30
# 2021-02-22    190.90
# 2021-03-01    141.40
# 2021-03-08    258.20
# 2021-03-15    184.36
# 2021-03-22    308.73
# 2021-03-29    172.11
# 2021-04-05    176.96
# 2021-04-12    137.21
# 2021-04-19     87.38
# 2021-04-26    103.26
# 2021-05-03    229.37
# Name: Cost ($), dtype: float64

# %%
#b.index = pd.to_datetime(b['date'],format='%m/%d/%y %I:%M%p')

data.index = pd.to_datetime(data['Week'], format = '%y/%m/%d')
df2 = data.groupby(data.index.month)['Cost ($)'].sum()
df2.head()
# Out:
# Week
# 1     154.79
# 2     834.91
# 3    1064.80
# 4     504.81
# 5     229.37
# Name: Cost ($), dtype: float64

# %%
type(data['Payment ($)'][0])
# Out:
# str

# %%
data['Ratio'] = data['Clicks'] / data['Impressions']
data['Ratio'] = data['Ratio'].fillna(0)
data['Overall Profit'] = data['Payment ($)'] - data['Cost ($)']
data
# Out:
#                  Week                        Campaign  \
# Week
# 2021-01-25 2021-01-25             EK_Generic_Swimming
# 2021-01-25 2021-01-25             EK_Generic_Swimming
# 2021-01-25 2021-01-25        EK_Generic_Quad-Tok_Yoga
# 2021-01-25 2021-01-25             EK_Generic_Swimming
# 2021-01-25 2021-01-25          EK_Generic_Swimming_UK
# ...               ...                             ...
# 2021-05-03 2021-05-03             EK_Generic_Swimming
# 2021-05-03 2021-05-03        EK_Generic_Quad-Tok_Yoga
# 2021-05-03 2021-05-03  EK_Generic_Tri-Tok_Reservation
# 2021-05-03 2021-05-03     EK_Generic_Quad-Tok_Pilates
# 2021-05-03 2021-05-03     EK_Generic_Quad-Tok_Pilates
#
#                                             Ad group Keyword type  \
# Week
# 2021-01-25             Pool_Reservation_System_Exact        Exact
# 2021-01-25                    Pool_Booking_App_Exact        Exact
# 2021-01-25        Yoga_Studio_Booking_Software_Broad        Broad
# ...

# %%
type(data["Week"][0])
# Out:
# pandas._libs.tslibs.timestamps.Timestamp
